# %%
import json
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#import openweathermapy.core as owm
#import os
#import csv
import seaborn as sns

import gmaps
import gmaps.geojson_geometries

from Project_Gas_Library import f_strToDate, f_EIA_ExtractData_Range, f_EIA_ListSeries, f_EIA_ExtractData, f_PlotData, f_EIA_PlotData, \
f_WorldWeather_ExtractData, f_EIA_PlotData_Range, f_PlotData, f_EIA_PlotData_Stack_Range, f_EIA_PlotData_Mod_Range, f_EIA_PlotData_Mod, f_Census_ExtractData, diff_month, calculate_color

from datetime import datetime
from dateutil.relativedelta import relativedelta
from calendar import monthrange

from api_keys import worldweather_key, EIA_key

from matplotlib.pyplot import cm
from citipy import citipy
from pprint import pprint

from matplotlib.cm import viridis
from matplotlib.colors import to_hex

from census import Census

# %%
eia_api_key = EIA_key
url = "http://api.eia.gov/series/"

series_id = "NG.N9100US3.M"
valx, valy, title, country, unit = f_EIA_ExtractData(url,eia_api_key,series_id)
x =  f_PlotData(valx, valy, title, unit)

list_series = []
list_series.append(series_id)
f_EIA_PlotData(list_series,url,eia_api_key,title)

#Generate pricing chart
# Out:
# c:\users\carlton lewis\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
list_series_1 = ["NG.N9100US3.M", "NG.N9102US3.M", "NG.N9103US3.M"]
f_EIA_PlotData(list_series_1,url,eia_api_key,"Monthly Imports Prices")

# %%
list_series_2 = ["NG.N9100US3.A", "NG.N9102US3.A", "NG.N9103US3.A"]
f_EIA_PlotData(list_series_2,url,eia_api_key,"Annual Imports Prices")

# %%
list_series_4 = ["NG.N3010US2.A", "NG.N3020US2.A", "NG.N3035US2.A", "NG.N3025US2.A", "NG.N3045US2.A", "NG.N3060US2.A"]
f_EIA_PlotData(list_series_4,url,eia_api_key,"Total Customer Consumption by Sector")

# %%
list_series_5 = ["NG.N9100US3.M", "NG.N9102US3.M", "NG.N9103US3.M"]
f_EIA_PlotData(list_series_5,url,eia_api_key,"Monthly Imports Prices")

# %%
list_series_6 = ["NG.N9130US3.A", "NG.N9132US3.A", "NG.N9133US3.A"]
f_EIA_PlotData(list_series_6,url,eia_api_key,"Annual Export Prices")

# %%
ini_date = "2000-12-1"
end_date = "2018-12-1"

  
list_series_8 = ["NG.NA1500_SCA_4.A", "NG.NA1500_SIL_4.A", "NG.NA1500_SNY_4.A", "NG.NA1500_SMI_4.A", "NG.NA1500_SOH_4.A", "NG.NA1500_SPA_4.A", 
                 "NG.NA1500_SNJ_4.A", "NG.NA1500_STX_4.A", "NG.NA1500_SIN_4.A", "NG.NA1500_SWI_4.A", "NG.NA1500_SMN_4.A", "NG.NA1500_SME_4.A", 
                 "NG.NA1500_SHI_4.A", "NG.NA1500_SID_4.A", "NG.NA1500_SIA_4.A", "NG.NA1500_SKS_4.A", "NG.NA1500_SAL_4.A", "NG.NA1500_SAK_4.A", 
                 "NG.NA1500_SAZ_4.A", "NG.NA1500_SAR_4.A", "NG.NA1500_SCO_4.A", "NG.NA1500_SCT_4.A", "NG.NA1500_SDE_4.A", "NG.NA1500_SDC_4.A", 
                 "NG.NA1500_SFL_4.A", "NG.NA1500_SGA_4.A", "NG.NA1500_SKY_4.A", "NG.NA1500_SLA_4.A", "NG.NA1500_SMD_4.A", "NG.NA1500_SMA_4.A",  
                 "NG.NA1500_SMS_4.A", "NG.NA1500_SMO_4.A", "NG.NA1500_SMT_4.A", "NG.NA1500_SNE_4.A", "NG.NA1500_SNV_4.A", 
                 "NG.NA1500_SNH_4.A",  "NG.NA1500_SNM_4.A",  "NG.NA1500_SNC_4.A", 
                 "NG.NA1500_SND_4.A",  "NG.NA1500_SOK_4.A", "NG.NA1500_SOR_4.A",  
                 "NG.NA1500_SRI_4.A", "NG.NA1500_SSC_4.A", "NG.NA1500_SSD_4.A", "NG.NA1500_STN_4.A",  "NG.NA1500_SUT_4.A",
                 "NG.NA1500_SVT_4.A", "NG.NA1500_SVA_4.A", "NG.NA1500_SWA_4.A", "NG.NA1500_SWV_4.A", "NG.NA1500_SWY_4.A"]


f_EIA_PlotData_Stack_Range(list_series_8,url,eia_api_key,"Consumer Consumption by State",ini_date,end_date)
# Out:
# ['California Natural Gas % of Total Residential Deliveries, Annual', 'Illinois Natural Gas % of Total Residential Deliveries, Annual', 'New York Natural Gas % of Total Residential Deliveries, Annual', 'Michigan Natural Gas % of Total Residential Deliveries, Annual', 'Ohio Natural Gas % of Total Residential Deliveries, Annual', 'Pennsylvania Natural Gas % of Total Residential Deliveries, Annual', 'New Jersey Natural Gas % of Total Residential Deliveries, Annual', 'Texas Natural Gas % of Total Residential Deliveries, Annual', 'Indiana Natural Gas % of Total Residential Deliveries, Annual', 'Wisconsin Natural Gas % of Total Residential Deliveries, Annual', 'Minnesota Natural Gas % of Total Residential Deliveries, Annual', 'Maine Natural Gas % of Total Residential Deliveries, Annual', 'Hawaii Natural Gas % of Total Residential Deliveries, Annual', 'Idaho Natural Gas % of Total Residential Deliveries, Annual', 'Iowa Natural Gas % of Total Residential Deliveries, Annual', 'Kansas Natural Gas % of Total Residential Deliveries, Annual', 'Alabama Natural Gas % of Total Residential Deliveries, Annual', 'Alaska Natural Gas % of Total Residential Deliveries, Annual', 'Arizona Natural Gas % of Total Residential Deliveries, Annual', 'Arkansas Natural Gas % of Total Residential Deliveries, Annual', 'Colorado Natural Gas % of Total Residential Deliveries, Annual', 'Connecticut Natural Gas % of Total Residential Deliveries, Annual', 'Delaware Natural Gas % of Total Residential Deliveries, Annual', 'District of Columbia Natural Gas % of Total Residential Deliveries, Annual', 'Florida Natural Gas % of Total Residential Deliveries, Annual', 'Georgia Natural Gas % of Total Residential Deliveries, Annual', 'Kentucky Natural Gas % of Total Residential Deliveries, Annual', 'Louisiana Natural Gas % of Total Residential Deliveries, Annual', 'Maryland Natural Gas % of Total Residential Deliveries, Annual', 'Massachusetts Natural Gas % of Total Residential Deliveries, Annual', 'Mississippi Natural Gas % of Total Residential Deliveries, Annual', 'Missouri Natural Gas % of Total Residential Deliveries, Annual', 'Montana Natural Gas % of Total Residential Deliveries, Annual', 'Nebraska Natural Gas % of Total Residential Deliveries, Annual', 'Nevada Natural Gas % of Total Residential Deliveries, Annual', 'New Hampshire Natural Gas % of Total Residential Deliveries, Annual', 'New Mexico Natural Gas % of Total Residential Deliveries, Annual', 'North Carolina Natural Gas % of Total Residential Deliveries, Annual', 'North Dakota Natural Gas % of Total Residential Deliveries, Annual', 'Oklahoma Natural Gas % of Total Residential Deliveries, Annual', 'Oregon Natural Gas % of Total Residential Deliveries, Annual', 'Rhode Island Natural Gas % of Total Residential Deliveries, Annual', 'South Carolina Natural Gas % of Total Residential Deliveries, Annual', 'South Dakota Natural Gas % of Total Residential Deliveries, Annual', 'Tennessee Natural Gas % of Total Residential Deliveries, Annual', 'Utah Natural Gas % of Total Residential Deliveries, Annual', 'Vermont Natural Gas % of Total Residential Deliveries, Annual', 'Virginia Natural Gas % of Total Residential Deliveries, Annual', 'Washington Natural Gas % of Total Residential Deliveries, Annual', 'West Virginia Natural Gas % of Total Residential Deliveries, Annual', 'Wyoming Natural Gas % of Total Residential Deliveries, Annual']

# %%
list_series_7 = ["NG.N9130US3.M", "NG.N9132US3.M", "NG.N9133US3.M"]
f_EIA_PlotData(list_series_7,url,eia_api_key,"Monthly Export Prices")

# %%
ini_date = "2000-12-1"
end_date = "2018-12-1"

  
list_series_8 = ["NG.NA1500_SCA_4.A", "NG.NA1500_SIL_4.A", "NG.NA1500_SNY_4.A", "NG.NA1500_SMI_4.A", "NG.NA1500_SOH_4.A", "NG.NA1500_SPA_4.A", 
                 "NG.NA1500_SNJ_4.A", "NG.NA1500_STX_4.A", "NG.NA1500_SIN_4.A", "NG.NA1500_SWI_4.A"]


f_EIA_PlotData_Stack_Range(list_series_8,url,eia_api_key,"Consumer Consumption by State",ini_date,end_date)
# Out:
# ['California Natural Gas % of Total Residential Deliveries, Annual', 'Illinois Natural Gas % of Total Residential Deliveries, Annual', 'New York Natural Gas % of Total Residential Deliveries, Annual', 'Michigan Natural Gas % of Total Residential Deliveries, Annual', 'Ohio Natural Gas % of Total Residential Deliveries, Annual', 'Pennsylvania Natural Gas % of Total Residential Deliveries, Annual', 'New Jersey Natural Gas % of Total Residential Deliveries, Annual', 'Texas Natural Gas % of Total Residential Deliveries, Annual', 'Indiana Natural Gas % of Total Residential Deliveries, Annual', 'Wisconsin Natural Gas % of Total Residential Deliveries, Annual']
