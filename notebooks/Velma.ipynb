# %%
import pandas as pd
excel_file = '../data/rawdata/EIA-StatetoStateCapacity.xlsx'
MajorPipe_Summary = pd.read_excel(open(excel_file, 'rb'), sheet_name='Major Pipeline Summary', header=0)
MajorPipe_Summary.head(3)
# Out:
#                                           Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0  Major Pipeline Crossing Multiple State Borders...        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2                                                NaN   Pipeline    Segment
#
#    Unnamed: 3 Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# 0         NaN        NaN         NaN         NaN         NaN         NaN
# 1         NaN        NaN         NaN         NaN         NaN         NaN
# 2  State From   State To      2018.0      2017.0      2016.0      2015.0
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2      2014.0       2013.0       2012.0       2011.0       2010.0
#
#    Unnamed: 14  Unnamed: 15  Unnamed: 16
# 0          NaN          NaN          NaN
# ...

# %%
column_names = MajorPipe_Summary.columns
column_names
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
#df = (pd.read_excel('UF_AGT702-M.xlsx', skiprows=2, sheetname='Report').dropna(how='all', axis=1))
MajorPipe_Summary = (pd.read_excel(excel_file, skiprows=2, sheet_name='0')
                     .dropna(how='all', axis=1))
MajorPipe_Summary
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/xlrd/book.py in sheet_by_name(self, sheet_name)
#     473         try:
# --> 474             sheetx = self._sheet_names.index(sheet_name)
#     475         except ValueError:
#
# ValueError: '0' is not in list
#
# During handling of the above exception, another exception occurred:
#
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-38-d906e813cc2e> in <module>
#       1 #df = (pd.read_excel('UF_AGT702-M.xlsx', skiprows=2, sheetname='Report').dropna(how='all', axis=1))
# ----> 2 MajorPipe_Summary = (pd.read_excel(excel_file, skiprows=2, sheet_name='0')
#       3                      .dropna(how='all', axis=1))
#       4 MajorPipe_Summary
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
csv_file = '../data/rawdata/EIA_CSV/MajorPipelineSummary.csv'
MajorPipe_Summary1 = pd.read_csv(csv_file, header=0,skip_blank_lines=True)
MajorPipe_Summary1
# Out:
#      Major Pipeline Crossing Multiple State Borders (Capacity in MMcfd)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# ...

# %%
column_names1 = MajorPipe_Summary1.columns
column_names1
# Out:
# Index(['Major Pipeline Crossing Multiple State Borders (Capacity in MMcfd)',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16'],
#       dtype='object')

# %%
#df = (pd.read_excel('UF_AGT702-M.xlsx', skiprows=2, sheetname='Report').dropna(how='all', axis=1))
